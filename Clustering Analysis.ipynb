# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("EastWestAirlines.csv")
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.isna().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
df[["ID#","Balance","Qual_miles","cc1_miles","cc2_miles","cc3_miles","Bonus_miles","Bonus_trans","Flight_miles_12mo","Flight_trans_12","Days_since_enroll","Award?"]]=sc.fit_transform(df[["ID#","Balance","Qual_miles","cc1_miles","cc2_miles","cc3_miles","Bonus_miles","Bonus_trans","Flight_miles_12mo","Flight_trans_12","Days_since_enroll","Award?"]])

# %%
df1=df.copy()

# %%
df2=df.iloc[:,:]

# %% [markdown]
# # Dendogram

# %%
import scipy.cluster.hierarchy as sch
sch.dendrogram(sch.linkage(df2,method="complete"))
plt.figure(figsize=(20, 12))
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc=AgglomerativeClustering(n_clusters=5,affinity="euclidean",linkage="complete")
hc.fit(df)
# Out:
# AgglomerativeClustering(affinity='euclidean', linkage='complete', n_clusters=5)

# %%
ych=hc.fit_predict(df2)

# %%
ych
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
df2["cluster"]=ych
df2
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1    -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2    -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3    -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4    -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
# ...        ...       ...         ...        ...        ...        ...
# 3994  1.725097 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767
# 3995  1.725958 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767
# 3996  1.726820 -0.000043   -0.186299   0.683121  -0.098242  -0.062767
# 3997  1.727682 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767
# 3998  1.728543 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %% [markdown]
# # KMEANS

# %%
r=df.copy()
r
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1    -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2    -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3    -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4    -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
# ...        ...       ...         ...        ...        ...        ...
# 3994  1.725097 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767
# 3995  1.725958 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767
# 3996  1.726820 -0.000043   -0.186299   0.683121  -0.098242  -0.062767
# 3997  1.727682 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767
# 3998  1.728543 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range (1,11):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(df.iloc[:,:])
  wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [47987.999999999985,
#  39018.880665640376,
#  34530.745849931925,
#  30616.60913611714,
#  26894.79534090421,
#  24324.647600615397,
#  20922.723634478436,
#  19330.223298975157,
#  18020.638266550348,
#  16847.572414023645]

# %%
sns.lineplot(x=range(1,11),y=wcss)
# Out:
# <Axes: >

# %%
from sklearn.metrics import  silhouette_score

# %%
kmeans=KMeans(n_clusters=8)
predict=kmeans.fit_predict(df.iloc[:,:])

# %%
predict
# Out:
# array([0, 0, 0, ..., 1, 5, 5])

# %%
df["cluster_values"]=predict
df
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1    -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2    -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3    -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4    -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
# ...        ...       ...         ...        ...        ...        ...
# 3994  1.725097 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767
# 3995  1.725958 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767
# 3996  1.726820 -0.000043   -0.186299   0.683121  -0.098242  -0.062767
# 3997  1.727682 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767
# 3998  1.728543 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
df[["cluster_values"]]
# Out:
#       cluster_values
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  7
# ...              ...
# 3994               5
# 3995               5
# 3996               1
# 3997               5
# 3998               5
#
# [3999 rows x 1 columns]

# %% [markdown]
# # DBSCAN

# %%
r
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1    -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2    -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3    -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4    -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
# ...        ...       ...         ...        ...        ...        ...
# 3994  1.725097 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767
# 3995  1.725958 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767
# 3996  1.726820 -0.000043   -0.186299   0.683121  -0.098242  -0.062767
# 3997  1.727682 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767
# 3998  1.728543 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
from sklearn.neighbors import NearestNeighbors
nn=NearestNeighbors(n_neighbors=8)
nbrs=nn.fit(r)
distance,indices=nbrs.kneighbors(r)

# %%
distance=np.sort(distance,axis=0)
distance=distance[:,1]
plt.plot(distance)

# %%
distance
# Out:
# array([2.42270462e-03, 2.42270462e-03, 4.69027727e-03, ...,
#        6.66765339e+00, 6.68121018e+00, 7.58357087e+00])

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan=DBSCAN(eps=0.9,min_samples=13)
dbscan.fit_predict(r)
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
r["clusters"]=dbscan.labels_
r
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1    -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2    -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3    -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4    -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
# ...        ...       ...         ...        ...        ...        ...
# 3994  1.725097 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767
# 3995  1.725958 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767
# 3996  1.726820 -0.000043   -0.186299   0.683121  -0.098242  -0.062767
# 3997  1.727682 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767
# 3998  1.728543 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
r["clusters"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4      -1
#        ..
# 3994    1
# 3995    1
# 3996    1
# 3997    0
# 3998    0
# Name: clusters, Length: 3999, dtype: int64
